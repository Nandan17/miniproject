# %%
import os
import pickle
import warnings
import numpy as np
from sklearn.mixture import GMM
from FeaturesExtractor import FeaturesExtractor
# Out:
# /home/mukund/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/least_angle.py:35: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps,
# /home/mukund/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/least_angle.py:597: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /home/mukund/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/least_angle.py:836: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /home/mukund/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# /home/mukund/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/least_angle.py:1074: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=1, eps=np.finfo(np.float).eps,
# /home/mukund/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/least_angle.py:1306: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=1, eps=np.finfo(np.float).eps,
# /home/mukund/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/least_angle.py:1442: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# /home/mukund/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/randomized_l1.py:152: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   precompute=False, eps=np.finfo(np.float).eps,
# /home/mukund/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/randomized_l1.py:318: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, random_state=None,
# /home/mukund/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/randomized_l1.py:575: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=4 * np.finfo(np.float).eps, n_jobs=1,
# /home/mukund/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/online_lda.py:31: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps

# %%
import sklearn
print(sklearn.version)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-5f3d7c53cb51> in <module>
#       1 import sklearn
# ----> 2 print(sklearn.version)
#
# AttributeError: module 'sklearn' has no attribute 'version'

# %%
warnings.filterwarnings("ignore")

# %%
class ModelsTrainer:

    def __init__(self, females_files_path, males_files_path):
        self.females_training_path = females_files_path
        self.males_training_path   = males_files_path
        self.features_extractor    = FeaturesExtractor()

    def process(self):
        females, males = self.get_file_paths(self.females_training_path,
                                             self.males_training_path)
        # collect voice features
        female_voice_features = self.collect_features(females)
        male_voice_features   = self.collect_features(males)
        # generate gaussian mixture models
        females_gmm = GMM(n_components = 16, n_iter = 200, covariance_type='diag', n_init = 3)
        males_gmm   = GMM(n_components = 16, n_iter = 200, covariance_type='diag', n_init = 3)
        # fit features to models
        females_gmm.fit(female_voice_features)
        males_gmm.fit(male_voice_features)
        # save models
        self.save_gmm(females_gmm, "females")
        self.save_gmm(males_gmm,   "males")

    def get_file_paths(self, females_training_path, males_training_path):
        # get file paths
        females = [ os.path.join(females_training_path, f) for f in os.listdir(females_training_path) ]
        males   = [ os.path.join(males_training_path, f) for f in os.listdir(males_training_path) ]
        return females, males

    def collect_features(self, files):
        """
    	Collect voice features from various speakers of the same gender.

    	Args:
    	    files (list) : List of voice file paths.

    	Returns:
    	    (array) : Extracted features matrix.
    	"""
        features = np.asarray(())
        # extract features for each speaker
        for file in files:
            print("%5s %10s" % ("PROCESSNG ", file))
            # extract MFCC & delta MFCC features from audio
            vector    = self.features_extractor.extract_features(file)
            # stack the features
            if features.size == 0:  features = vector
            else:                   features = np.vstack((features, vector))
        return features

    def save_gmm(self, gmm, name):
        """ Save Gaussian mixture model using pickle.

            Args:
                gmm        : Gaussian mixture model.
                name (str) : File name.
        """
        filename = name + ".gmm"
        with open(filename, 'wb') as gmm_file:
            pickle.dump(gmm, gmm_file)
        print ("%5s %10s" % ("SAVING", filename,))


if __name__== "__main__":
    models_trainer = ModelsTrainer("TrainingData/females", "TrainingData/males")
    models_trainer.process()
# Out:
# PROCESSNG  TrainingData/females/FemaleAngry22.wav
# PROCESSNG  TrainingData/females/FemaleHappy29.wav
# PROCESSNG  TrainingData/females/FemaleNeutral9.wav
# PROCESSNG  TrainingData/females/FemaleAngry19.wav
# PROCESSNG  TrainingData/females/FemaleNeutral37.wav
# PROCESSNG  TrainingData/females/FemaleNeutral13.wav
# PROCESSNG  TrainingData/females/FemaleNeutral4.wav
# PROCESSNG  TrainingData/females/FemaleHappy32.wav
# PROCESSNG  TrainingData/females/FemaleNeutral33.wav
# PROCESSNG  TrainingData/females/FemaleNeutral53.wav
# PROCESSNG  TrainingData/females/FemaleAngry5.wav
# PROCESSNG  TrainingData/females/FemaleHappy41.wav
# PROCESSNG  TrainingData/females/FemaleAngry8.wav
# PROCESSNG  TrainingData/females/FemaleHappy22.wav
# PROCESSNG  TrainingData/females/FemaleNeutral49.wav
# PROCESSNG  TrainingData/females/FemaleNeutral39.wav
# PROCESSNG  TrainingData/females/FemaleAngry30.wav
# PROCESSNG  TrainingData/females/FemaleNeutral34.wav
# PROCESSNG  TrainingData/females/FemaleAngry45.wav
# PROCESSNG  TrainingData/females/FemaleAngry20.wav
# PROCESSNG  TrainingData/females/FemaleNeutral41.wav
# PROCESSNG  TrainingData/females/FemaleHappy7.wav
# PROCESSNG  TrainingData/females/FemaleAngry17.wav
# PROCESSNG  TrainingData/females/FemaleAngry2.wav
# PROCESSNG  TrainingData/females/FemaleAngry43.wav
# PROCESSNG  TrainingData/females/FemaleNeutral16.wav
# PROCESSNG  TrainingData/females/FemaleHappy23.wav
# PROCESSNG  TrainingData/females/FemaleAngry3.wav
# PROCESSNG  TrainingData/females/FemaleNeutral11.wav
# PROCESSNG  TrainingData/females/FemaleNeutral38.wav
# PROCESSNG  TrainingData/females/FemaleAngry11.wav
# PROCESSNG  TrainingData/females/FemaleAngry46.wav
# PROCESSNG  TrainingData/females/FemaleAngry40.wav
# PROCESSNG  TrainingData/females/FemaleNeutral44.wav
# PROCESSNG  TrainingData/females/FemaleHappy43.wav
# PROCESSNG  TrainingData/females/FemaleHappy47.wav
# PROCESSNG  TrainingData/females/FemaleHappy36.wav
# PROCESSNG  TrainingData/females/FemaleAngry23.wav
# PROCESSNG  TrainingData/females/FemaleAngry37.wav
# PROCESSNG  TrainingData/females/FemaleHappy34.wav
# PROCESSNG  TrainingData/females/FemaleAngry35.wav
# PROCESSNG  TrainingData/females/FemaleHappy16.wav
# PROCESSNG  TrainingData/females/FemaleHappy45.wav
# PROCESSNG  TrainingData/females/FemaleAngry4.wav
# PROCESSNG  TrainingData/females/FemaleNeutral45.wav
# PROCESSNG  TrainingData/females/FemaleNeutral32.wav
# PROCESSNG  TrainingData/females/FemaleNeutral36.wav
# PROCESSNG  TrainingData/females/FemaleAngry27.wav
# PROCESSNG  TrainingData/females/FemaleAngry13.wav
# PROCESSNG  TrainingData/females/FemaleNeutral40.wav
# PROCESSNG  TrainingData/females/FemaleHappy50.wav
# PROCESSNG  TrainingData/females/FemaleHappy27.wav
# PROCESSNG  TrainingData/females/FemaleNeutral19.wav
# PROCESSNG  TrainingData/females/FemaleAngry9.wav
# PROCESSNG  TrainingData/females/FemaleNeutral48.wav
# PROCESSNG  TrainingData/females/FemaleHappy20.wav
# PROCESSNG  TrainingData/females/FemaleAngry25.wav
# PROCESSNG  TrainingData/females/FemaleAngry1.wav
# PROCESSNG  TrainingData/females/FemaleAngry28.wav
# PROCESSNG  TrainingData/females/FemaleNeutral15.wav
# PROCESSNG  TrainingData/females/FemaleNeutral23.wav
# PROCESSNG  TrainingData/females/FemaleNeutral30.wav
# PROCESSNG  TrainingData/females/FemaleHappy25.wav
# PROCESSNG  TrainingData/females/FemaleHappy49.wav
# PROCESSNG  TrainingData/females/FemaleAngry12.wav
# PROCESSNG  TrainingData/females/FemaleAngry52.wav
# PROCESSNG  TrainingData/females/FemaleNeutral24.wav
# PROCESSNG  TrainingData/females/FemaleHappy9.wav
# PROCESSNG  TrainingData/females/FemaleAngry36.wav
# PROCESSNG  TrainingData/females/FemaleNeutral46.wav
# PROCESSNG  TrainingData/females/FemaleNeutral20.wav
# PROCESSNG  TrainingData/females/FemaleNeutral43.wav
# PROCESSNG  TrainingData/females/FemaleNeutral21.wav
# PROCESSNG  TrainingData/females/FemaleHappy40.wav
# PROCESSNG  TrainingData/females/FemaleNeutral51.wav
# PROCESSNG  TrainingData/females/FemaleAngry10.wav
# PROCESSNG  TrainingData/females/FemaleNeutral14.wav
# PROCESSNG  TrainingData/females/FemaleHappy13.wav
# PROCESSNG  TrainingData/females/FemaleAngry7.wav
# PROCESSNG  TrainingData/females/FemaleNeutral29.wav
# PROCESSNG  TrainingData/females/FemaleHappy19.wav
# PROCESSNG  TrainingData/females/FemaleHappy12.wav
# PROCESSNG  TrainingData/females/FemaleHappy33.wav
# PROCESSNG  TrainingData/females/FemaleHappy46.wav
# PROCESSNG  TrainingData/females/FemaleAngry49.wav
# PROCESSNG  TrainingData/females/FemaleNeutral25.wav
# PROCESSNG  TrainingData/females/FemaleAngry31.wav
# PROCESSNG  TrainingData/females/FemaleNeutral3.wav
# PROCESSNG  TrainingData/females/FemaleNeutral26.wav
# PROCESSNG  TrainingData/females/FemaleHappy28.wav
# PROCESSNG  TrainingData/females/FemaleAngry51.wav
# PROCESSNG  TrainingData/females/FemaleHappy30.wav
# PROCESSNG  TrainingData/females/FemaleNeutral18.wav
# PROCESSNG  TrainingData/females/FemaleHappy48.wav
# PROCESSNG  TrainingData/females/FemaleHappy15.wav
# PROCESSNG  TrainingData/females/FemaleHappy3.wav
# PROCESSNG  TrainingData/females/FemaleHappy38.wav
# PROCESSNG  TrainingData/females/FemaleHappy17.wav
# PROCESSNG  TrainingData/females/FemaleNeutral52.wav
# PROCESSNG  TrainingData/females/FemaleAngry34.wav
# PROCESSNG  TrainingData/females/FemaleAngry50.wav
# PROCESSNG  TrainingData/females/FemaleAngry6.wav
# PROCESSNG  TrainingData/females/FemaleAngry33.wav
# PROCESSNG  TrainingData/females/FemaleAngry53.wav
# PROCESSNG  TrainingData/females/FemaleNeutral31.wav
# PROCESSNG  TrainingData/females/FemaleAngry18.wav
# PROCESSNG  TrainingData/females/FemaleHappy18.wav
# PROCESSNG  TrainingData/females/FemaleAngry16.wav
# PROCESSNG  TrainingData/females/FemaleNeutral1.wav
# PROCESSNG  TrainingData/females/FemaleHappy53.wav
# PROCESSNG  TrainingData/females/FemaleNeutral28.wav
# PROCESSNG  TrainingData/females/FemaleNeutral10.wav
# PROCESSNG  TrainingData/females/FemaleHappy35.wav
# PROCESSNG  TrainingData/females/FemaleAngry14.wav
# PROCESSNG  TrainingData/females/FemaleAngry41.wav
# PROCESSNG  TrainingData/females/FemaleHappy24.wav
# PROCESSNG  TrainingData/females/FemaleAngry15.wav
# PROCESSNG  TrainingData/females/FemaleAngry39.wav
# PROCESSNG  TrainingData/females/FemaleAngry24.wav
# PROCESSNG  TrainingData/females/FemaleHappy51.wav
# PROCESSNG  TrainingData/females/FemaleNeutral17.wav
# PROCESSNG  TrainingData/females/FemaleNeutral35.wav
# PROCESSNG  TrainingData/females/FemaleAngry48.wav
# PROCESSNG  TrainingData/females/FemaleNeutral12.wav
# PROCESSNG  TrainingData/females/FemaleNeutral22.wav
# PROCESSNG  TrainingData/females/FemaleHappy5.wav
# PROCESSNG  TrainingData/females/FemaleHappy44.wav
# PROCESSNG  TrainingData/females/FemaleNeutral8.wav
# PROCESSNG  TrainingData/females/FemaleHappy37.wav
# PROCESSNG  TrainingData/females/FemaleHappy42.wav
# PROCESSNG  TrainingData/females/FemaleNeutral27.wav
# PROCESSNG  TrainingData/females/FemaleAngry38.wav
# PROCESSNG  TrainingData/females/FemaleHappy2.wav
# PROCESSNG  TrainingData/females/FemaleNeutral7.wav
# PROCESSNG  TrainingData/females/FemaleHappy6.wav
# PROCESSNG  TrainingData/females/FemaleAngry47.wav
# PROCESSNG  TrainingData/females/FemaleHappy14.wav
# PROCESSNG  TrainingData/females/FemaleNeutral50.wav
# PROCESSNG  TrainingData/females/FemaleHappy1.wav
# PROCESSNG  TrainingData/females/FemaleAngry26.wav
# PROCESSNG  TrainingData/females/FemaleHappy26.wav
# PROCESSNG  TrainingData/females/FemaleHappy10.wav
# PROCESSNG  TrainingData/females/FemaleHappy39.wav
# PROCESSNG  TrainingData/females/FemaleHappy11.wav
# PROCESSNG  TrainingData/females/FemaleHappy52.wav
# PROCESSNG  TrainingData/females/FemaleNeutral5.wav
# PROCESSNG  TrainingData/females/FemaleAngry32.wav
# PROCESSNG  TrainingData/females/FemaleHappy31.wav
# PROCESSNG  TrainingData/females/FemaleNeutral2.wav
# PROCESSNG  TrainingData/females/FemaleNeutral54.wav
# PROCESSNG  TrainingData/females/FemaleAngry42.wav
# PROCESSNG  TrainingData/females/FemaleNeutral42.wav
# PROCESSNG  TrainingData/females/FemaleHappy21.wav
# PROCESSNG  TrainingData/females/FemaleHappy4.wav
# PROCESSNG  TrainingData/females/FemaleNeutral47.wav
# PROCESSNG  TrainingData/females/FemaleNeutral6.wav
# PROCESSNG  TrainingData/females/FemaleHappy8.wav
# PROCESSNG  TrainingData/females/FemaleAngry44.wav
# PROCESSNG  TrainingData/females/FemaleAngry29.wav
# PROCESSNG  TrainingData/females/FemaleAngry21.wav
# PROCESSNG  TrainingData/males/MaleHappy14.wav
# PROCESSNG  TrainingData/males/MaleHappy21.wav
# PROCESSNG  TrainingData/males/MaleAngry68.wav
# PROCESSNG  TrainingData/males/MaleHappy52.wav
# PROCESSNG  TrainingData/males/MaleHappy60.wav
# PROCESSNG  TrainingData/males/MaleNeutral43.wav
# PROCESSNG  TrainingData/males/MaleHappy51.wav
# PROCESSNG  TrainingData/males/MaleNeutral61.wav
# PROCESSNG  TrainingData/males/MaleHappy59.wav
# PROCESSNG  TrainingData/males/MaleNeutral18.wav
# PROCESSNG  TrainingData/males/MaleAngry60.wav
# PROCESSNG  TrainingData/males/MaleNeutral67.wav
# PROCESSNG  TrainingData/males/MaleNeutral71.wav
# PROCESSNG  TrainingData/males/MaleNeutral63.wav
# PROCESSNG  TrainingData/males/MaleNeutral72.wav
# PROCESSNG  TrainingData/males/MaleAngry52.wav
# PROCESSNG  TrainingData/males/MaleAngry47.wav
# PROCESSNG  TrainingData/males/MaleHappy15.wav
# PROCESSNG  TrainingData/males/MaleAngry56.wav
# PROCESSNG  TrainingData/males/MaleHappy48.wav
# PROCESSNG  TrainingData/males/MaleNeutral58.wav
# PROCESSNG  TrainingData/males/MaleNeutral66.wav
# PROCESSNG  TrainingData/males/MaleNeutral14.wav
# PROCESSNG  TrainingData/males/MaleHappy53.wav
# PROCESSNG  TrainingData/males/MaleAngry51.wav
# PROCESSNG  TrainingData/males/MaleHappy67.wav
# PROCESSNG  TrainingData/males/MaleAngry19.wav
# PROCESSNG  TrainingData/males/MaleAngry65.wav
# PROCESSNG  TrainingData/males/MaleAngry17.wav
# PROCESSNG  TrainingData/males/MaleAngry63.wav
# PROCESSNG  TrainingData/males/MaleNeutral50.wav
# PROCESSNG  TrainingData/males/MaleNeutral24.wav
# PROCESSNG  TrainingData/males/MaleHappy41.wav
# PROCESSNG  TrainingData/males/MaleNeutral64.wav
# PROCESSNG  TrainingData/males/MaleNeutral15.wav
# PROCESSNG  TrainingData/males/MaleHappy37.wav
# PROCESSNG  TrainingData/males/MaleAngry55.wav
# PROCESSNG  TrainingData/males/MaleAngry44.wav
# PROCESSNG  TrainingData/males/MaleAngry20.wav
# PROCESSNG  TrainingData/males/MaleAngry54.wav
# PROCESSNG  TrainingData/males/MaleNeutral69.wav
# PROCESSNG  TrainingData/males/MaleAngry61.wav
# PROCESSNG  TrainingData/males/MaleHappy39.wav
# PROCESSNG  TrainingData/males/MaleHappy57.wav
# PROCESSNG  TrainingData/males/MaleNeutral65.wav
# PROCESSNG  TrainingData/males/MaleNeutral21.wav
# PROCESSNG  TrainingData/males/MaleNeutral20.wav
# PROCESSNG  TrainingData/males/MaleAngry38.wav
# PROCESSNG  TrainingData/males/MaleNeutral56.wav
# PROCESSNG  TrainingData/males/MaleNeutral57.wav
# PROCESSNG  TrainingData/males/MaleNeutral62.wav
# PROCESSNG  TrainingData/males/MaleAngry24.wav
# PROCESSNG  TrainingData/males/MaleAngry49.wav
# PROCESSNG  TrainingData/males/MaleAngry59.wav
# PROCESSNG  TrainingData/males/MaleNeutral55.wav
# PROCESSNG  TrainingData/males/MaleNeutral22.wav
# PROCESSNG  TrainingData/males/MaleHappy71.wav
# PROCESSNG  TrainingData/males/MaleAngry67.wav
# PROCESSNG  TrainingData/males/MaleNeutral45.wav
# PROCESSNG  TrainingData/males/MaleAngry53.wav
# PROCESSNG  TrainingData/males/MaleAngry71.wav
# PROCESSNG  TrainingData/males/MaleHappy72.wav
# PROCESSNG  TrainingData/males/MaleHappy19.wav
# PROCESSNG  TrainingData/males/MaleNeutral48.wav
# PROCESSNG  TrainingData/males/MaleAngry62.wav
# PROCESSNG  TrainingData/males/MaleHappy69.wav
# PROCESSNG  TrainingData/males/MaleAngry22.wav
# PROCESSNG  TrainingData/males/MaleNeutral52.wav
# PROCESSNG  TrainingData/males/MaleAngry13.wav
# PROCESSNG  TrainingData/males/MaleNeutral16.wav
# PROCESSNG  TrainingData/males/MaleAngry69.wav
# PROCESSNG  TrainingData/males/MaleAngry14.wav
# PROCESSNG  TrainingData/males/MaleHappy58.wav
# PROCESSNG  TrainingData/males/MaleHappy22.wav
# PROCESSNG  TrainingData/males/MaleAngry58.wav
# PROCESSNG  TrainingData/males/MaleNeutral53.wav
# PROCESSNG  TrainingData/males/MaleAngry45.wav
# PROCESSNG  TrainingData/males/MaleNeutral42.wav
# PROCESSNG  TrainingData/males/MaleHappy63.wav
# PROCESSNG  TrainingData/males/MaleNeutral38.wav
# PROCESSNG  TrainingData/males/MaleHappy16.wav
# PROCESSNG  TrainingData/males/MaleHappy45.wav
# PROCESSNG  TrainingData/males/MaleAngry66.wav
# PROCESSNG  TrainingData/males/MaleHappy42.wav
# PROCESSNG  TrainingData/males/MaleAngry48.wav
# PROCESSNG  TrainingData/males/MaleHappy68.wav
# PROCESSNG  TrainingData/males/MaleNeutral70.wav
# PROCESSNG  TrainingData/males/MaleAngry72.wav
# PROCESSNG  TrainingData/males/MaleAngry64.wav
# PROCESSNG  TrainingData/males/MaleNeutral37.wav
# PROCESSNG  TrainingData/males/MaleAngry50.wav
# PROCESSNG  TrainingData/males/MaleHappy65.wav
# PROCESSNG  TrainingData/males/MaleNeutral39.wav
# PROCESSNG  TrainingData/males/MaleNeutral44.wav
# PROCESSNG  TrainingData/males/MaleAngry43.wav
# PROCESSNG  TrainingData/males/MaleHappy46.wav
# PROCESSNG  TrainingData/males/MaleNeutral19.wav
# PROCESSNG  TrainingData/males/MaleNeutral51.wav
# PROCESSNG  TrainingData/males/MaleHappy13.wav
# PROCESSNG  TrainingData/males/MaleHappy40.wav
# PROCESSNG  TrainingData/males/MaleHappy66.wav
# PROCESSNG  TrainingData/males/MaleNeutral47.wav
# PROCESSNG  TrainingData/males/MaleNeutral59.wav
# PROCESSNG  TrainingData/males/MaleAngry15.wav
# PROCESSNG  TrainingData/males/MaleHappy43.wav
# PROCESSNG  TrainingData/males/MaleAngry16.wav
# PROCESSNG  TrainingData/males/MaleNeutral49.wav
# PROCESSNG  TrainingData/males/MaleAngry42.wav
# PROCESSNG  TrainingData/males/MaleAngry21.wav
# PROCESSNG  TrainingData/males/MaleHappy44.wav
# PROCESSNG  TrainingData/males/MaleAngry37.wav
# PROCESSNG  TrainingData/males/MaleHappy62.wav
# PROCESSNG  TrainingData/males/MaleAngry57.wav
# PROCESSNG  TrainingData/males/MaleAngry23.wav
# PROCESSNG  TrainingData/males/MaleNeutral40.wav
# PROCESSNG  TrainingData/males/MaleHappy17.wav
# PROCESSNG  TrainingData/males/MaleNeutral17.wav
# PROCESSNG  TrainingData/males/MaleNeutral46.wav
# PROCESSNG  TrainingData/males/MaleHappy55.wav
# PROCESSNG  TrainingData/males/MaleHappy50.wav
# PROCESSNG  TrainingData/males/MaleHappy64.wav
# PROCESSNG  TrainingData/males/MaleHappy47.wav
# PROCESSNG  TrainingData/males/MaleNeutral60.wav
# PROCESSNG  TrainingData/males/MaleHappy38.wav
# PROCESSNG  TrainingData/males/MaleHappy20.wav
# PROCESSNG  TrainingData/males/MaleHappy70.wav
# PROCESSNG  TrainingData/males/MaleAngry41.wav
# PROCESSNG  TrainingData/males/MaleHappy18.wav
# PROCESSNG  TrainingData/males/MaleHappy49.wav
# PROCESSNG  TrainingData/males/MaleAngry18.wav
# PROCESSNG  TrainingData/males/MaleNeutral41.wav
# PROCESSNG  TrainingData/males/MaleHappy54.wav
# PROCESSNG  TrainingData/males/MaleNeutral54.wav
# PROCESSNG  TrainingData/males/MaleHappy23.wav
# PROCESSNG  TrainingData/males/MaleAngry39.wav
# PROCESSNG  TrainingData/males/MaleNeutral23.wav
# PROCESSNG  TrainingData/males/MaleNeutral68.wav
# PROCESSNG  TrainingData/males/MaleAngry46.wav
# PROCESSNG  TrainingData/males/MaleHappy61.wav
# PROCESSNG  TrainingData/males/MaleAngry70.wav
# PROCESSNG  TrainingData/males/MaleNeutral13.wav
# PROCESSNG  TrainingData/males/MaleAngry40.wav
# PROCESSNG  TrainingData/males/MaleHappy24.wav
# PROCESSNG  TrainingData/males/MaleHappy56.wav
# SAVING females.gmm
# SAVING  males.gmm
